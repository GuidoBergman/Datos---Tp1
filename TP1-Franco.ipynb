# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('train_values.csv')

# %%
df1
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
labels = pd.read_csv('train_labels.csv')

# %%
labels
# Out:
#         building_id  damage_grade
# 0            802906             3
# 1             28830             2
# 2             94947             3
# 3            590882             2
# 4            201944             3
# ...             ...           ...
# 260596       688636             2
# 260597       669485             3
# 260598       602512             3
# 260599       151409             2
# 260600       747594             3
#
# [260601 rows x 2 columns]

# %%
df = df1.merge(labels, on='building_id')

# %%
df
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
df.age.value_counts().plot(kind='bar',figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
df.count_floors_pre_eq.value_counts().plot(kind='bar',figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
df.groupby('age').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.groupby('height_percentage').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='height_percentage'>

# %%
df
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
df.groupby('count_floors_pre_eq').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='count_floors_pre_eq'>

# %%
df.groupby('area_percentage').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='area_percentage'>

# %%
df.groupby('foundation_type').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='foundation_type'>

# %%
df.groupby('land_surface_condition').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='land_surface_condition'>

# %%
df.groupby('geo_level_1_id').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='geo_level_1_id'>

# %%
df.groupby('geo_level_1_id').agg({'damage_grade':'mean'}).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='geo_level_1_id'>

# %%
df
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
top3damageRegion = df.loc[(df['geo_level_1_id'] == 17) | (df['geo_level_1_id'] == 18) | (df['geo_level_1_id'] == 21)]
top3damageRegion.groupby('geo_level_1_id').agg({'age':'mean'})
# Out:
#                       age
# geo_level_1_id
# 17              22.871682
# 18              30.846660
# 21              22.022298

# %%
top3damageRegion.groupby('geo_level_1_id').agg({'age':'mean'}).age.mean()
# Out:
# 25.24688025354872

# %%
df.age.mean()
# Out:
# 26.535028645323695

# %%
top3damageRegion.groupby('geo_level_1_id').agg({'count_floors_pre_eq':'mean'})
# Out:
#                 count_floors_pre_eq
# geo_level_1_id
# 17                         2.315729
# 18                         1.901537
# 21                         2.526160

# %%
top3damageRegion.groupby('geo_level_1_id').agg({'count_floors_pre_eq':'mean'}).count_floors_pre_eq.mean()
# Out:
# 2.2478086455679787

# %%
df.count_floors_pre_eq.mean()
# Out:
# 2.1297232167182782

# %%
top3damageRegion.geo_level_2_id.nunique()
# Out:
# 149

# %%
topRegion = df.loc[df['geo_level_1_id'] == 17]

# %%
topRegion.geo_level_2_id.nunique()
# Out:
# 79

# %%
df_train = df

# %%
df_train["sum_of_uses"] = df_train.loc[:,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other"]].sum(axis=1)

# %%
df_train
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
df_train.sum_of_uses.value_counts()
# Out:
# 0    231445
# 2     28599
# 3       557
# Name: sum_of_uses, dtype: int64

# %%
df_train.loc[df_train.sum_of_uses==3,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other","sum_of_uses"]]
# Out:
#         has_secondary_use  has_secondary_use_agriculture  \
# 304                     1                              1
# 1408                    1                              1
# 1593                    1                              1
# 2329                    1                              1
# 3704                    1                              0
# ...                   ...                            ...
# 256746                  1                              1
# 257939                  1                              1
# 258184                  1                              1
# 258755                  1                              1
# 260002                  1                              1
#
#         has_secondary_use_hotel  has_secondary_use_rental  \
# 304                           0                         0
# 1408                          0                         0
# 1593                          0                         0
# ...

# %%
df_train["sum_of_uses_2"] = df_train.loc[:,[        
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
df_train.sum_of_uses_2.value_counts()
# Out:
# 0    232222
# 1     28379
# Name: sum_of_uses_2, dtype: int64

# %%
df_train_uses = df_train.loc[:,["building_id",             
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]]

# %%
df_train_uses
# Out:
#         building_id  has_secondary_use_agriculture  has_secondary_use_hotel  \
# 0            802906                              0                        0
# 1             28830                              0                        0
# 2             94947                              0                        0
# 3            590882                              0                        0
# 4            201944                              0                        0
# ...             ...                            ...                      ...
# 260596       688636                              0                        0
# 260597       669485                              0                        0
# 260598       602512                              0                        0
# 260599       151409                              0                        0
# 260600       747594                              0                        0
#
# ...

# %%
df_train_uses["sum"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
#df_train_uses['sum'].value_counts()

# %% [markdown]
# Se omiten las columnas others para el analisis ya que generalmente estan acompñadas por una de estas columnas

# %%
df_train_uses["type_of_use"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].idxmax(axis = 1, skipna = True)

# %%
df_train_uses

# %%
df_train_uses[df_train_uses.building_id==333020]

# %%
df_train_uses['type_of_use'] = df_train_uses.loc[df_train_uses['sum'] == 1,'type_of_use'].replace({'has_secondary_use_':''},regex=True)

# %%
df_train_uses[df_train_uses['sum'] == 1]

# %%
df_train_uses['type_of_use'].value_counts().sort_values(ascending=False)

# %%
dfPorCimiento = df.groupby('foundation_type').agg({'damage_grade':'mean'}).reset_index()
dfPorCimiento

# %%
df.groupby('land_surface_condition').agg({'damage_grade':'mean'})

# %%
values=df.groupby('land_surface_condition').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values

# %%
categories=['n','o','t']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('land_surface_condition').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]


plt.figure(figsize=(10,10))
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=10)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
    
plt.style.use("seaborn-whitegrid")    
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")
plt.title('Daño promedio por condicion de la superficie terrestre',size=20)

# Show the graph
plt.show()

# %%
df.groupby('foundation_type').agg({'damage_grade':'mean'})

# %%
categories=['h','i','r','u','w']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('foundation_type').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por tipo de cimiento de la edificacion',size=20)
# Show the graph
plt.show()

# %%
def porcentaje(x):
    return (x.mean())/3

df.groupby('age').agg({'damage_grade':'mean'}).sort_values(by='age',ascending=True).plot(kind='bar',figsize=(15,10))

# %%
df

# %%
df.roof_type.value_counts()

# %%
categories=['n','q','x']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('roof_type').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por tipo de techo usado',size=20)
# Show the graph
plt.show()

# %%
df.plan_configuration.value_counts()

# %%
categories=['d', 'q', 'u', 's', 'c', 'a', 'o', 'm', 'n', 'f']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('plan_configuration').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por formato de construcción de la edificación (para diseño sísmico)',size=20)
# Show the graph
plt.show()

# %%
df.ground_floor_type.value_counts()

# %%
categories=['f','x','v','z','m']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('ground_floor_type').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por tipo de construcción usado en la planta baja',size=20)
# Show the graph
plt.show()

# %%
df.other_floor_type.value_counts()

# %%
categories=['q','x','j','s']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('other_floor_type').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por tipo de construcción usado en la planta baja',size=20)
# Show the graph
plt.show()

# %%
values
# Out:
# [2.042893356423964,
#  2.315751261480379,
#  1.6074160292650481,
#  2.2973439513901677,
#  2.042893356423964]

# %%
df.position.value_counts()

# %%
categories=['s','t','j','o']
N = len(categories)

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.groupby('position').agg({'damage_grade':'mean'}).damage_grade.tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
 
plt.figure(figsize=(10,10))    
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=20)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ['1','2','3'], color="grey", size=15)
plt.ylim(0,3)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

plt.style.use("seaborn-whitegrid")

plt.title('Daño promedio por tipo de construcción usado en la planta baja',size=20)
# Show the graph
plt.show()

# %%
df.columns

# %%
df.groupby('geo_level_2_id').agg({'geo_level_3_id':pd.Series.nunique}).sort_values(by='geo_level_3_id',ascending=False)

# %%
df_train["sum_of_uses"] = df_train.loc[:,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other"]].sum(axis=1)

# %%
df_train

# %%
df_train.sum_of_uses.value_counts()

# %%
df_train.loc[df_train.sum_of_uses==3,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other","sum_of_uses"]]

# %%
df_train["sum_of_uses_2"] = df_train.loc[:,[        
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
df_train.sum_of_uses_2.value_counts()

# %%
df_train_uses = df_train.loc[:,["building_id",             
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]]

# %%
df_train_uses

# %%
df_train_uses["sum"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
#df_train_uses['sum'].value_counts()

# %% [markdown]
# Se omiten las columnas others para el analisis ya que generalmente estan acompñadas por una de estas columnas

# %%
df_train_uses["type_of_use"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].idxmax(axis = 1, skipna = True)

# %%
df_train_uses

# %%
df_train_uses[df_train_uses.building_id==333020]

# %%
df_train_uses['type_of_use'] = df_train_uses.loc[df_train_uses['sum'] == 1,'type_of_use'].replace({'has_secondary_use_':''},regex=True)

# %%
df_train_uses[df_train_uses['sum'] == 1]

# %%
df_train_uses['type_of_use'].value_counts().sort_values(ascending=False)

# %%
plt.figure(figsize=(15,8))
sns.countplot(y='type_of_use', data=df_train_uses ,order = df_train_uses['type_of_use'].value_counts().index)
plt.title('Tipo de uso de las construcciones dañadas', fontsize=20)
plt.show()

# %% [markdown]
# Conclusion

# %% [markdown]
# Las construcciones principalmente afectadas fueron las agricolas. Se observa un importante daño tambien en lo que son edificaciones de hoteleria,
#
# Cabe aclarar que para este caso finalmente tuvimos que omitir las columnas o has_secondary_use y has_secondary_use_other

# %%
df_train['has_secondary_use_hotel'].value_counts()

# %%
df_train_merge = df_train.merge(df_train_uses)

# %%
df_train_merge

# %%
df_train_merge.type_of_use.fillna('others', inplace=True)

# %%
df_train_merge[df_train_merge.age>500].type_of_use.value_counts()

# %%
df_train_merge.type_of_use.value_counts()

# %%
df_train["sum_of_uses"] = df_train.loc[:,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other"]].sum(axis=1)

# %%
df_train

# %%
df_train.sum_of_uses.value_counts()

# %%
df_train.loc[df_train.sum_of_uses==3,["has_secondary_use"             
,"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"
,"has_secondary_use_other","sum_of_uses"]]

# %%
df_train["sum_of_uses_2"] = df_train.loc[:,[        
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
df_train.sum_of_uses_2.value_counts()

# %%
df_train_uses = df_train.loc[:,["building_id",             
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]]

# %%
df_train_uses

# %%
df_train_uses["sum"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].sum(axis=1)

# %%
#df_train_uses['sum'].value_counts()

# %% [markdown]
# Se omiten las columnas others para el analisis ya que generalmente estan acompñadas por una de estas columnas

# %%
df_train_uses["type_of_use"] = df_train_uses.loc[:,[            
"has_secondary_use_agriculture"   
,"has_secondary_use_hotel"           
,"has_secondary_use_rental"         
,"has_secondary_use_institution" 
,"has_secondary_use_school"  
,"has_secondary_use_industry"
,"has_secondary_use_health_post"
,"has_secondary_use_gov_office"       
,"has_secondary_use_use_police"]].idxmax(axis = 1, skipna = True)

# %%
df_train_uses

# %%
df_train_uses[df_train_uses.building_id==333020]

# %%
df_train_uses['type_of_use'] = df_train_uses.loc[df_train_uses['sum'] == 1,'type_of_use'].replace({'has_secondary_use_':''},regex=True)

# %%
df_train_uses[df_train_uses['sum'] == 1]

# %%
df_train_uses['type_of_use'].value_counts().sort_values(ascending=False)

# %%
plt.figure(figsize=(15,8))
sns.countplot(y='type_of_use', data=df_train_uses ,order = df_train_uses['type_of_use'].value_counts().index)
plt.title('Tipo de uso de las construcciones dañadas', fontsize=20)
plt.show()

# %% [markdown]
# Conclusion

# %% [markdown]
# Las construcciones principalmente afectadas fueron las agricolas. Se observa un importante daño tambien en lo que son edificaciones de hoteleria,
#
# Cabe aclarar que para este caso finalmente tuvimos que omitir las columnas o has_secondary_use y has_secondary_use_other

# %%
df_train['has_secondary_use_hotel'].value_counts()

# %%
df_train_merge = df_train.merge(df_train_uses)

# %%
df_train_merge

# %%
df_train_merge.type_of_use.fillna('others', inplace=True)

# %%
df_train_merge[df_train_merge.age>500].type_of_use.value_counts()

# %%
df = df_train_merge

# %%
df.groupby('geo_level_2_id').agg({'type_of_use':'count'})

# %%
df.groupby('geo_level_2_id').agg({'damage_grade':'mean'}).sort_values(ascending=False, by='damage_grade').head(10).plot(kind='bar',figsize=(15,10))

# %%
grouped = df.groupby('geo_level_2_id').agg({ 'damage_grade' : ['mean','count'] }).sort_values(ascending=False, by=('damage_grade','mean'))
forPlot = grouped.loc[grouped['damage_grade','count']>100].head(20)
forPlot.plot(kind='bar',y=('damage_grade','mean'),figsize=(15,15))

# %%
df.groupby(['geo_level_1_id','geo_level_2_id','geo_level_3_id']).agg({'damage_grade': 'sum'}).sort_values(by='damage_grade',ascending=False).head(10).plot(kind='bar',figsize=(15,10))

# %%
scatter = df.groupby(['area_percentage','height_percentage']).agg({'damage_grade':'sum'}).reset_index()
scatter['damage_grade'] = scatter['damage_grade']/15
scatter.plot(kind='scatter',x='area_percentage',y='height_percentage',s='damage_grade',alpha=0.5,figsize=(20,15))

# %%
df.groupby('geo_level_1_id').agg({'damage_grade':['sum','count','mean']})

# %%
#hue="damage_grade"

sns.relplot(
data=df_train,
x="area_percentage", y="height_percentage",sizes=(10,1000),legend='full',
 height=10,aspect=1,hue="age",hue_norm=(0,10),palette=sns.color_palette("ch:s=.25,rot=-.25", as_cmap=True)

)
plt.title('Altura vs Area', fontsize=20)

# %%
df.groupby(['geo_level_1_id','geo_level_2_id','geo_level_3_id']).agg({'damage_grade': ['sum','count','mean']}).sort_values(by=('damage_grade','sum'),ascending=False)

# %%
ad = df.groupby(['geo_level_1_id','geo_level_2_id','geo_level_3_id'])\
        .agg({'damage_grade':['sum','count']}).sort_values(by=('damage_grade','sum')\
        ,ascending=False)
ad.columns = [('','Cantidad de edificaciones'), ('','Danio total')]
ad.head(20).plot(rot=45,kind='bar',figsize=(20,15))
#grouped.columns = grouped.columns.get_level_values(0) + grouped.columns.get_level_values(1)
#grouped.reset_index(inplace=True)
#grouped.columns = ['geo_level_1_id','geo_level_2_id','geo_level_3_id','Cantidad de edificaciones','Daño total']
#grouped.head(20).plot(rot=45,kind='bar',,figsize=(20,15))

# %%
aux = values[['damage_grade', 'foundation_type', 'geo_level_1_id']]
aux = aux.groupby(['damage_grade', 'foundation_type']).count()
aux = aux.unstack(0)
# Separo el tipo de cimiento r porque tiene una escala muy distinta a 
# las de los demas
g = aux.loc[['h', 'i', 'u', 'w'],:].plot.bar(figsize=(10,5), rot=0)
g.set_title("Grado de daño en las edificaciones por tipo de cimientos",
            fontsize=25)
g.set_xlabel("Tipo de cimientos",fontsize=18)
g.set_ylabel("Cantidad de edificaciones", fontsize=18)
plt.legend(['Daño bajo','Daño mediano','Daño serio'])

# %%
df.groupby(['foundation_type','damage_grade']).agg({'damage_grade':'count'}).unstack().plot(kind='bar',figsize=(15,10))

# %%
df.groupby(['foundation_type','damage_grade']).agg({'damage_grade':'count'}).unstack().plot(kind='bar',figsize=(15,10))

# %%
df.groupby(['geo_level_1_id','geo_level_2_id','geo_level_3_id'])\
        .agg({'damage_grade':['sum','count']}).sort_values(by=('damage_grade','sum')\
        ,ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["foundation_type"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por tipo de cimiento")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["land_surface_condition"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por condicion de la tierra")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["roof_type"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por tipo de techo")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["ground_floor_type"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por tipo de construccion de la planta baja")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["other_floor_type"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por tipo de construccion de los pisos superiores")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["position"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por orientacion de la edificacion")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = df["plan_configuration"], hue = df["damage_grade"])
plt.title("Grado de daño en las edificaciones por formato de construcción de la edificación (para diseño sísmico)")
plt.show()

# %%
df.groupby(['plan_configuration','damage_grade']).agg({'damage_grade':'count'})
